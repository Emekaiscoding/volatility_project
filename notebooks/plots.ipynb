# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np
import exchange_calendars as xcals

# %%
aapl= yf.Ticker("aapl")
aapl

aapl_historical = aapl.history(start="2026-06-01", end="2026-06-17", interval="1m")
aapl_historical
